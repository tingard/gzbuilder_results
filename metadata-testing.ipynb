# %% [markdown]
# # Metadata testing

# %%
import json
import numpy as np
import pandas as pd
from astropy.io import fits
from astropy.table import Table
from astropy.coordinates import SkyCoord, match_coordinates_sky
import astropy.units as u
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gzb_subjects = pd.read_csv('lib/galaxy-builder-subjects.csv', index_col=0) \
    .query('subject_set_id >= 20561 and subject_set_id <= 21182')
gzb_metadata = gzb_subjects['metadata'].apply(json.loads).apply(pd.Series)

# %%
nsa_table = Table.read('../source_files/nsa_v1_0_1.fits', memmap=True)

# %%
gz_nsa_table = Table.read('../source_files/NSA_GalaxyZoo.fits', memmap=True)

# %%
gz_nsa_positions = gz_nsa_table[['dr7objid', 'ra_2', 'dec_2']].to_pandas().set_index('dr7objid').rename(columns={'ra_2': 'ra', 'dec_2': 'dec'})

# %%
gzb_positions = gzb_metadata.rename(columns={'SDSS dr7 id': 'dr7objid'})[['ra', 'dec', 'dr7objid']].dropna()

# %%
gzb_coords = SkyCoord(*gzb_positions[['ra', 'dec']].values.T, unit=u.degree)
nsa_coords = SkyCoord(*gz_nsa_positions[['ra', 'dec']].values.T, unit=u.degree)
idx, sep, _ = match_coordinates_sky(gzb_coords, nsa_coords)

# %%
MATCHING_THRESHOLD = 4 # distance in arcseconds

has_match = sep.arcsecond < MATCHING_THRESHOLD
print('{:.2%} have position matches within {} arcseconds'.format(has_match.sum() / has_match.size, MATCHING_THRESHOLD))
# Out:
# 97.30% have position matches within 4 arcseconds

# %%
dr7_matched_df = pd.concat((
    gz_nsa_df.reindex(gzb_positions.dr7objid.astype(np.int64).values).reset_index(),
    gzb_positions.add_prefix('gzb_').reset_index(),
), axis=1)

# %%
did_not_dr7_match = dr7_matched_df['ra'].isna()
print('{:.2%} have dr7objid matches'.format(1 - did_not_dr7_match.sum() / len(did_not_dr7_match)))
# Out:
# 97.30% have dr7objid matches

# %%
gzb_metadata[did_not_dr7_match.values]
# Out:
#                     ra   Run        dec Field Rerun Camcol  NSA id  \
# subject_id
# 20901989    118.684814  5045  14.607033    46   301      4  485056
# 20901991    161.501450  4504  34.967144    44   301      3  431909
# 20902025    130.367538  3635  27.634048   134   301      3  316963
# 20902056    242.090912  3910   4.722453   212   301      5  393042
# 21686495    118.684814  5045  14.607033    46   301      4  485056
# 21686497    161.501450  4504  34.967144    44   301      3  431909
# 21686554    130.367538  3635  27.634048   134   301      3  316963
# 21686585    242.090912  3910   4.722453   212   301      5  393042
#
#                                                       #models  redshift  \
# subject_id
# 20901989    [{'frame': 0, 'model': 'GALAXY_BUILDER_DIFFERE...  0.000018
# 20901991    [{'frame': 0, 'model': 'GALAXY_BUILDER_DIFFERE...  0.006592
# 20902025    [{'frame': 0, 'model': 'GALAXY_BUILDER_DIFFERE...  0.020635
# 20902056    [{'frame': 0, 'model': 'GALAXY_BUILDER_DIFFERE...  0.036879
# 21686495    [{'frame': 0, 'model': 'GALAXY_BUILDER_DIFFERE...  0.000018
# 21686497    [{'frame': 0, 'model': 'GALAXY_BUILDER_DIFFERE...  0.006592
# 21686554    [{'frame': 0, 'model': 'GALAXY_BUILDER_DIFFERE...  0.020635
# 21686585    [{'frame': 0, 'model': 'GALAXY_BUILDER_DIFFERE...  0.036879
#
#            Common name         SDSS dr7 id  \
# subject_id
# 20901989       Unknown  587741421632356667
# 20901991       Unknown  587739097518047289
# 20902025       Unknown  588016840174075960
# 20902056       Unknown  587730023338279050
# 21686495       Unknown  587741421632356667
# 21686497       Unknown  587739097518047289
# 21686554       Unknown  588016840174075960
# 21686585       Unknown  587730023338279050
#
#                                                   Url to view  #isModelling  \
# subject_id
# 20901989    [skyserver link](+tab+http://skyserver.sdss.or...          True
# 20901991    [skyserver link](+tab+http://skyserver.sdss.or...          True
# 20902025    [skyserver link](+tab+http://skyserver.sdss.or...          True
# 20902056    [skyserver link](+tab+http://skyserver.sdss.or...          True
# 21686495    [skyserver link](+tab+http://skyserver.sdss.or...          True
# 21686497    [skyserver link](+tab+http://skyserver.sdss.or...          True
# 21686554    [skyserver link](+tab+http://skyserver.sdss.or...          True
# 21686585    [skyserver link](+tab+http://skyserver.sdss.or...          True
#
#            Sersic axis ratio              Estimated distance  \
# subject_id
# 20901989            0.436513  0.001208746456541121 * c / H_0
# 20901991            0.821631  0.007313817739486694 * c / H_0
# 20902025            0.695032    0.0206304844468832 * c / H_0
# 20902056            0.373941    0.0368216335773468 * c / H_0
# 21686495            0.436513  0.001208746456541121 * c / H_0
# 21686497            0.821631  0.007313817739486694 * c / H_0
# 21686554            0.695032    0.0206304844468832 * c / H_0
# 21686585            0.373941    0.0368216335773468 * c / H_0
#
#            Petrosian radius (degrees)
# subject_id
# 20901989                     6.728252
# 20901991                    17.295427
# 20902025                    13.524295
# 20902056                     9.522999
# 21686495                     6.728252
# 21686497                    17.295427
# 21686554                    13.524295
# 21686585                     9.522999
