# %% [markdown]
# # Bulge / Total exploration
#
# This notebook reads in files created elsewhere containing galaxy builder models (aggregate, best individual and optimized best individual) and compares the Bulge / Total fraction to results in the literature

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from jax.config import config
config.update("jax_enable_x64", True)

# %%
import os
import json
import numpy as np
import pandas as pd
from copy import deepcopy
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import lib.galaxy_utilities as gu
import gzbuilder_analysis.parsing as parsing
import gzbuilder_analysis.aggregation as aggregation
import gzbuilder_analysis.rendering as rendering
from gzbuilder_analysis.rendering.jax.sersic import _b, sersic_ltot
import gzbuilder_analysis.fitting as fitting
from gzbuilder_analysis.fitting.optimizer import Optimizer
import jax.numpy as jnp
from asinh_cmap import asinh_cmap
from IPython.display import HTML

# %% [markdown]
# Read in the required files:

# %%
fitting_metadata = pd.read_pickle('lib/fitting_metadata.pkl').sort_index()

# %%
sid_list = np.loadtxt('lib/subject-id-list.csv', dtype='u8')

# catalogues to compare to
simard_df = pd.read_csv('lib/simard-catalog_fixed-n.csv', index_col=0)
simard_df_free = pd.read_csv('lib/simard-catalog_free-n.csv', index_col=0)
lackner_nb1 = pd.read_csv('lib/lackner_nb1.csv', index_col=0)
lackner_nb4 = pd.read_csv('lib/lackner_nb4.csv', index_col=0)

# %%
from gzbuilder_analysis import load_fit_results
fit_results = load_fit_results('output_files/tuning_results')
# Out:
# 100%|██████████| 296/296 [00:05<00:00, 54.84it/s]

# %%
# fit_model_path = 'output_files/tuning_results'
# fit_models = pd.Series([], dtype=object)
# with tqdm(os.listdir(fit_model_path)) as bar:
#     for f in bar:
#          if re.match(r'[0-9]+\.pickle.gz', f):
#                 fit_models[int(f.split('.')[0])] = pd.read_pickle(
#                     os.path.join(fit_model_path, f)
#                 )
# fit_models = fit_models.apply(pd.Series)

# %%
gzb_f = fit_results.bulge_frac + fit_results.bar_frac

# %%
bulge_fractions = pd.concat((
    simard_df.__B_T_r.rename('Simard_EdeV'),
    simard_df.e__B_T_r.rename('Simard_EdeV_err'),
    simard_df_free.__B_T_r.rename('Simard_ES'),
    simard_df_free.e__B_T_r.rename('Simard_ES_err'),
    lackner_nb1.BULGE_TO_TOT_R.rename('Lackner_EE'),
    lackner_nb1.BULGE_TO_TOT_R_ERR.rename('Lackner_EE_err'),
    lackner_nb4.BULGE_TO_TOT_R.rename('Lackner_EdeV'),
    lackner_nb4.BULGE_TO_TOT_R_ERR.rename('Lackner_EdeV_err'),
    gzb_f.rename('GZB'),
), axis=1)

# %%
bulge_fractions.head()
# Out:
#           Simard_EdeV  Simard_EdeV_err  Simard_ES  Simard_ES_err  Lackner_EE  \
# 20901989         0.55             0.01       0.47           0.01         NaN
# 20901990         0.02             0.01       0.62           0.07         NaN
# 20901991         0.25             0.01       0.24           0.01         NaN
# 20901992         0.30             0.01       0.80           0.02    0.219332
# 20901993         0.06             0.01       0.99           0.01    0.068589
#
#           Lackner_EE_err  Lackner_EdeV  Lackner_EdeV_err       GZB
# 20901989             NaN           NaN               NaN  0.198253
# 20901990             NaN           NaN               NaN  0.000000
# 20901991             NaN           NaN               NaN  0.075809
# 20901992        0.004558      0.834976          0.008337  0.321542
# 20901993        0.002351      0.089206          0.008295  0.061619

# %%
display_column_map = {
    c: '\n'.join(c.split('_')[::-1])
          .replace('Simard', '(Simard, 2011)')
          .replace('Lackner', '(Lackner, 2012)')
          .replace('EE', 'Exponential + Exponential')
          .replace('EdeV', 'Exponential + De Vaucoulers')
          .replace('ES', 'Exponential + Sérsic')
          .replace('GZB', 'This work')
    for c in bulge_fractions.columns
}

# %% [markdown]
# First, we'll do a quick and dirty pairplot, and colour-code things by which model type was best fit in Lackner (2012):

# %%
types = lackner_nb1['TYPE'].reindex(bulge_fractions.index).fillna('N/A').rename('types')
types.value_counts()
# Out:
# ser    104
# N/A     72
# exp     50
# nb4     38
# nb1     30
# dvc      2
# Name: types, dtype: int64

# %% [markdown]
# We'll turn off the kde / hist plots on the diagonals as the low number counts will cause errors

# %%
g = sns.pairplot(
    pd.concat((
        bulge_fractions[[c for c in bulge_fractions.columns if not c.endswith('_err')]].rename(columns=display_column_map),
        types,
    ), axis=1),
    hue='types',
    diag_kind='none',
)
offdiag = (ax for i, axs in enumerate(g.axes) for j, ax in enumerate(axs) if i != j)
for ax in offdiag:
    ax.add_line(plt.Line2D((0, 1), (0, 1), c='k', alpha=0.2))
    ax.set_xlim(-0.1, 1.1)
    ax.set_ylim(-0.1, 1.1)

# %% [markdown]
# Even when comparing the same model being fit by different surveys, we see a lot of scatter (though a notable 1:1 relationship). Sérsic index is evidently a very difficult parameter to model, but impacts bulge fractions immensely!

# %% [markdown]
# Now just plot Galaxy builder results vs those in the catalog:

# %%
f, ax = plt.subplots(ncols=4, figsize=(13.5, 4), dpi=100, sharex=True, sharey=True)
model_types = np.unique(types)
ax[0].set_xlim(-0.1, 1.1)
ax[0].set_ylim(-0.1, 1.1);

for i, k in enumerate(('Simard_EdeV', 'Simard_ES', 'Lackner_EE', 'Lackner_EdeV')):
    df = bulge_fractions.query(f'{k}_err < 1')[['GZB', k, f'{k}_err']]
    df.plot.scatter(k, 'GZB', xerr=f'{k}_err', ax=ax[i], c=f'C1', s=10, alpha=1)
#     ax[i].set_title(display_column_map.get(k, ''))
    ax[i].add_line(plt.Line2D((-0.1, 1.1), (-0.1, 1.1), c='k', alpha=0.2))
    ax[i].set_title(display_column_map.get(k, ''))
    ax[i].set_xlabel('Bulge fraction')
ax[0].set_xlim(-0.1, 1.1)
ax[0].set_ylim(-0.1, 1.1);
ax[0].set_ylabel('Central Component Fraction,\nGalaxy Builder')
plt.tight_layout();
plt.savefig('method-paper-plots/bulge_fraction_scatter.pdf', bbox_inches='tight')

# %% [markdown]
# We'll restrict the comparison to Simard to where they identified a bulge+disk decomposition was needed ($P_{pS} \le 0.32$), and Lackner (2012) to only use models where that model was deemed the best model type (i.e only compare to Exp+deV models when the Exp+deV model was determined to be better than the Exp+Exp / S / etc.. models)

# %%
f, ax = plt.subplots(ncols=4, figsize=(13.5, 4), dpi=100, sharex=True, sharey=True)
model_types = np.unique(types)
ax[0].set_xlim(-0.1, 1.1)
ax[0].set_ylim(-0.1, 1.1);

for i, k in enumerate(('Simard_EdeV', 'Simard_ES', 'Lackner_EE', 'Lackner_EdeV')):
#     for j, t in enumerate(model_types):
    if 'Lackner' in k:
        t = 'nb1' if k == 'Lackner_EE' else 'nb4'
        df = bulge_fractions[types == t][['GZB', k, f'{k}_err']]
    else:
        mask = (simard_df.PpS <= 0.32)
        df = bulge_fractions[mask][['GZB', k, f'{k}_err']]#[types == t]
    df.plot.scatter(k, 'GZB', xerr=f'{k}_err', ax=ax[i], c=f'C1', s=10, alpha=1)
    ax[i].set_title(display_column_map.get(k, ''))
    ax[i].set_xlabel('Bulge fraction')
    ax[i].add_line(plt.Line2D((-0.1, 1.1), (-0.1, 1.1), c='k', alpha=0.2))
ax[0].set_xlim(-0.1, 1.1)
ax[0].set_ylim(-0.1, 1.1);
ax[0].set_ylabel('Central Component Fraction,\nGalaxy Builder')
plt.tight_layout();
plt.savefig('method-paper-plots/bulge_fraction_scatter_reduced.pdf', bbox_inches='tight')

# %% [markdown]
# We can use `seaborn.regplot` to eaily visualize the strength of the relationship (though outliers tend to throw this off, even when using `robust=True`

# %%
ROBUST = False

# %%
f, ax = plt.subplots(ncols=4, figsize=(13.5, 4), dpi=100, sharex=True, sharey=True)
model_types = np.unique(types)
ax[0].set_xlim(-0.1, 1.1)
ax[0].set_ylim(-0.1, 1.1);

for i, k in enumerate(('Simard_EdeV', 'Simard_ES', 'Lackner_EE', 'Lackner_EdeV')):
#     for j, t in enumerate(model_types):
    if 'Lackner' in k:
        t = 'nb1' if k == 'Lackner_EE' else 'nb4'
        df = bulge_fractions[types == t][['GZB', k, f'{k}_err']]
    else:
        mask = (simard_df.PpS <= 0.32)
        df = bulge_fractions[mask][['GZB', k, f'{k}_err']]#[types == t]
    df.plot.scatter(k, 'GZB', xerr=f'{k}_err', ax=ax[i], c=f'C1', s=10, alpha=1)
    sns.regplot(k, 'GZB', df, ax=ax[i], robust=ROBUST, scatter=False, color='k')
    ax[i].set_title(display_column_map.get(k, ''))
    ax[i].set_xlabel('Bulge fraction')
    ax[i].add_line(plt.Line2D((-0.1, 1.1), (-0.1, 1.1), c='k', alpha=0.2))

ax[0].set_xlim(-0.1, 1.1)
ax[0].set_ylim(-0.1, 1.1);
ax[0].set_ylabel('Central Component Fraction,\nGalaxy Builder')
plt.tight_layout();

# %% [markdown]
# Note that the gradient of the best-fit line is less than one for the Exponential + de Vaucoulers models, whereas it is greater than one (as observed by eye - `sns.regplot` is being thrown off by outliers) for the Exponential + Exponential model. This highlights the importance of reliable Sérsic indices in bulge+disc decomposition, which is definitely one problem our work does not adequately solve (you'd need a more robust fitting routine to address this).
#
# We can also make comparisons to Kruk (2018), who modelled a bar separately to the bulge (Exponential + Sérsic + Sérsic)

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u
gal_angle_df = pd.read_csv('lib/gal-metadata.csv', index_col=0)
sd = pd.read_csv('../source_files/Kruk2018_Table2_Table3.csv')
sd_coords = SkyCoord(ra=sd['ra']*u.degree, dec=sd['dec']*u.degree)

kruk_matches = pd.DataFrame([], columns=sd.columns)
with tqdm(fitting_metadata.index) as bar:
    for subject_id in bar:
        gal = gal_angle_df.loc[subject_id]
        sep = sd_coords.separation(
            SkyCoord(ra=gal['RA']*u.degree, dec=gal['DEC']*u.degree)
        )
        idxmin_sep = np.argmin(sep)
        if sep[idxmin_sep] < 1 * u.arcsec:
            kruk_matches.loc[subject_id] = sd.iloc[idxmin_sep]
# Out:
# 100%|██████████| 296/296 [00:02<00:00, 118.55it/s]

# %%
plt.figure(figsize=(6, 6))
plt.xlim(-0.1, 1.1)
plt.ylim(-0.1, 1.1)
df = pd.concat(
    ((kruk_matches.BT_r + kruk_matches.BarT_r).rename('Kruk'), gzb_f.rename('GZB')),
    axis=1
).dropna()
df.plot.scatter('Kruk', 'GZB', c=f'C1', s=30, alpha=1, ax=plt.gca())
sns.regplot(
    'Kruk', 'GZB',
    df,
    ax=plt.gca(),
    scatter=False,
    robust=ROBUST,
    color='k'
)

plt.gca().add_line(plt.Line2D((-1E3, 1E3), (-1E3, 1E3), c='k', alpha=0.2))
plt.xlabel('Kruk (2018) Central Fraction')
plt.ylabel('Galaxy Builder Central Fraction')
plt.xlim(-0.1, 1.1)
plt.ylim(-0.1, 1.1);

# %%
bulge_ns = fit_results.fit_model.apply(lambda m: m.get(('bulge', 'n'), np.nan)).dropna()

# %%
plt.figure(figsize=(12, 3))
sns.kdeplot(bulge_ns, label='This work')
plt.axvline(1, label='Exponential + Exponential\n(Lackner 2011)', c='C4')
plt.axvline(4, label='Exponential + de Vaucoulers\n(Simard 2011, Lackner 2012)', c='C5')
sns.kdeplot(simard_df_free['nb'].dropna(), label='Exponential + Sérsic\n(Simard, 2011)')
sns.kdeplot(kruk_matches['n_bulge'].replace(0, np.nan).dropna(), label='Exponential + Sérsic + Sérsic\nKruk (2018)')
plt.legend()
plt.xlabel(r'Bulge Sérsic $n$');
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# The above graph makes it immediately obvious why the Exponential + Sérsic model in Simard (2011) shows such poor agreement with other two-component models: its bulge Sérsic index varies dramatically from 0.5 to 8, while those in this work remain much lower.
