# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd

from gzbuilder_analysis import load_aggregation_results, load_fit_results, to_catalog

# %%
subject_data = pd.read_csv('lib/galaxy-builder-subjects.csv', index_col=0)

# %%
subject_data.subject_set_id.value_counts().sort_index()
# Out:
# 16292      7
# 16432     14
# 16601     14
# 20206     14
# 20561     98
# 20751    100
# 21182     98
# 26040     46
# 72464     32
# 76427    196
# 80112      9
# Name: subject_set_id, dtype: int64

# %%
aggregation_results = load_aggregation_results('output_files/aggregation_results')

# %%
fit_results = load_fit_results('output_files/tuning_results', ext='pickle.gz')

# %%
main_run_subject_sets = (20561, 20751, 21182)
main_run_subjects = subject_data.query('subject_set_id in @main_run_subject_sets')
catalog = to_catalog(fit_results, aggregation_results, main_run_subjects, validation_set_ids=(21182,))

# %%
catalog
# Out:
#                     galaxy_builder_id  is_validation          ra        dec  \
# dr7objid
# 587741421632356667           20901989          False  118.684814  14.607033
# 588007005234266362           20901990          False  123.420944  45.993744
# 587739097518047289           20901991          False  161.501450  34.967144
# 587745538906652834           20901992          False  148.692368  13.374738
# 587729773143851215           20901993          False  203.039398  -2.749252
# ...                               ...            ...         ...        ...
# 587739646738563164           21686611           True  150.760010  27.273951
# 588295842859778125           21686612           True  178.829437  50.799721
# 587742573220200621           21686613           True  165.220001  19.492830
# 587731681193754794           21686614           True  136.363129  44.143883
# 588017605238915235           21686615           True  235.474152  32.763084
#
#                        chisq  pogson_magnitude        flux    disk_Re  \
# dr7objid
# 587741421632356667  2.061733         17.058040  150.239461  16.994899
# 588007005234266362  2.037382         15.120098  895.284077  29.113959
# 587739097518047289  1.202357         15.071230  936.500350  40.133203
# 587745538906652834  1.219624         16.196725  332.131404  45.180131
# 587729773143851215  1.212138         15.325432  741.015476  25.782332
# ...                      ...               ...         ...        ...
# 587739646738563164  1.029773         16.246373  317.285861  15.330242
# 588295842859778125  1.277849         16.901857  173.483105  21.383529
# 587742573220200621  1.333235         16.809822  188.830155  18.785016
# 587731681193754794  2.166373         16.387356  278.648988  15.449011
# 588017605238915235  1.292542         17.090818  145.771538  16.112991
#
#                     disk_Re_err    disk_q  ...  bar_q_err     bar_n     bar_c  \
# dr7objid                                   ...
# 587741421632356667     2.780927  0.523041  ...   0.049401  0.300000  3.012111
# 588007005234266362     7.218963  0.907050  ...        NaN       NaN       NaN
# 587739097518047289     1.122460  0.826906  ...        NaN       NaN       NaN
# 587745538906652834     6.697548  0.424403  ...        NaN       NaN       NaN
# 587729773143851215     3.090927  0.704147  ...   0.074254  0.638294  6.000000
# ...                         ...       ...  ...        ...       ...       ...
# 587739646738563164     7.254938  0.876655  ...        NaN       NaN       NaN
# 588295842859778125     3.771267  0.505431  ...        NaN       NaN       NaN
# 587742573220200621     4.614360  0.577228  ...        NaN       NaN       NaN
# 587731681193754794     4.234503  0.509376  ...        NaN       NaN       NaN
# 588017605238915235     4.718557  0.432720  ...        NaN       NaN       NaN
#
#                     bar_fraction        pitch_angle_0       pitch_angle_1  \
# dr7objid
# 587741421632356667      0.192621                  NaN                 NaN
# 588007005234266362           NaN  -31.687253895793216  -30.34228525824123
# 587739097518047289           NaN                  NaN                 NaN
# 587745538906652834           NaN  -35.215893900486726                 NaN
# 587729773143851215      0.047542  -12.323320128604694  -17.52379207594454
# ...                          ...                  ...                 ...
# 587739646738563164           NaN                  NaN                 NaN
# 588295842859778125           NaN  -1.1801789822600595                 NaN
# 587742573220200621           NaN                  NaN                 NaN
# 587731681193754794           NaN                  NaN                 NaN
# 588017605238915235           NaN  -16.717107357721154                 NaN
#
#                           pitch_angle_2  pitch_angle_3  n_spirals  \
# dr7objid
# 587741421632356667                  NaN            NaN        0.0
# 588007005234266362  -17.988490203292493            NaN        3.0
# 587739097518047289                  NaN            NaN        0.0
# 587745538906652834                  NaN            NaN        1.0
# 587729773143851215                  NaN            NaN        2.0
# ...                                 ...            ...        ...
# 587739646738563164                  NaN            NaN        0.0
# 588295842859778125                  NaN            NaN        1.0
# 587742573220200621                  NaN            NaN        0.0
# 587731681193754794                  NaN            NaN        0.0
# 588017605238915235                  NaN            NaN        1.0
#
#                     spiral_fraction
# dr7objid
# 587741421632356667              NaN
# 588007005234266362         0.375292
# 587739097518047289              NaN
# 587745538906652834         0.064746
# 587729773143851215         0.066604
# ...                             ...
# 587739646738563164              NaN
# 588295842859778125         0.253138
# 587742573220200621              NaN
# 587731681193754794              NaN
# 588017605238915235         0.154042
#
# [296 rows x 32 columns]

# %%
catalog.dtypes
# Out:
# galaxy_builder_id      int64
# is_validation           bool
# ra                   float64
# dec                  float64
# chisq                float64
# pogson_magnitude     float64
# flux                 float64
# disk_Re              float64
# disk_Re_err          float64
# disk_q               float64
# disk_q_err           float64
# centre_dx            float64
# centre_dy            float64
# bulge_Re             float64
# bulge_Re_err         float64
# bulge_q              float64
# bulge_q_err          float64
# bulge_n              float64
# bulge_fraction       float64
# bar_Re               float64
# bar_Re_err           float64
# bar_q                float64
# bar_q_err            float64
# bar_n                float64
# bar_c                float64
# bar_fraction         float64
# pitch_angle_0         object
# pitch_angle_1         object
# pitch_angle_2         object
# pitch_angle_3         object
# n_spirals            float64
# spiral_fraction      float64
# dtype: object

# %%
catalog.to_csv('../source_files/galaxy-builder-catalogue.csv')

# %%
# !ls lib/simard*
# Out:
# lib/simard-catalog_fixed-n.csv lib/simard-catalog_free-n.csv

# %%
simard_df = pd.read_csv('lib/simard-catalog_fixed-n.csv', index_col=0)

# %%
(catalog
    .set_index('galaxy_builder_id')
    .eval('bulge_fraction + bar_fraction')
    .rename('bt')
    .to_frame()
    .assign(simard_bt=simard_df.__B_T_r)
    .dropna()
    .plot.scatter('simard_bt', 'bt')
)
plt.gca().add_line(plt.Line2D((0, 1), (0, 1), c='k', alpha=0.2))

# %%
simard_df.__B_T_r
# Out:
# subject_id
# 20901989    0.55
# 20901990    0.02
# 20901991    0.25
# 20901992    0.30
# 20901993    0.06
#             ...
# 21686611    0.07
# 21686612    0.24
# 21686613    0.43
# 21686614    0.15
# 21686615    0.35
# Name: __B_T_r, Length: 296, dtype: float64
